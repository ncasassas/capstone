# %%
import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt

# %%
def archivo_no_vacio(fpath):  
    return True if os.path.isfile(fpath) and os.path.getsize(fpath) > 0 else False

# %%
from collections import defaultdict
empresas_df =  pd.read_csv("constituents_csv.csv", sep=",")
empresas_df["Symbol"] = empresas_df["Symbol"].str.lower()
lista_sectores = list(empresas_df["Sector"])
dic_empresas_industria = defaultdict()
for index, accion in enumerate(empresas_df["Symbol"]):
    dic_empresas_industria[accion] = lista_sectores[index]

# %%
# con filtro fecha y filtro 500 empresas
list_files = os.listdir("Stocks1/")
dict_frames = dict() # dicccionario con todos los data frames que rellenaremos
dict_rendimientos = dict()

#recorremos todas las acciones en Stocks desde 2010 (Stocks1)
for nombre_archivo in list_files:
    
    #aplicamos filtro de 500 empresas
    index = nombre_archivo.find(".us")
    simple = nombre_archivo[0:index]
    if simple not in list(empresas_df["Symbol"]):
        continue
        
    path = f"Stocks1/{nombre_archivo}"
    
    # recorremos los archivos no vacios
    if archivo_no_vacio(path):
        
        df =  pd.read_csv(path, sep=",")
        df = df[['Date', 'Open', 'Close', 'Volume']]
        df['ticker'] = nombre_archivo.replace('.csv', '')
        df['Rendimiento'] = (df['Close'] - df['Open']) / df['Open']
        
        # quitamos los datos nulos
        df.dropna(subset=['Rendimiento'], inplace=True)
        
        df['Date']= pd.to_datetime(df['Date'], dayfirst = True)
        
        # filtramos para obtener los datos de hasta el 31 Dic de 2014
        df = df[(df['Date'] < '2015-01-01 00:00:00')]
        
        # se guarda el nombre sin .txt
        dict_frames[nombre_archivo.split(".csv")[0]] = df
        dict_rendimientos[nombre_archivo.split(".csv")[0]] = df[['Rendimiento']]
        
#Veamos una empresa

# %%
dict_frames['aapl.us']
# Out:
#            Date     Open    Close     Volume   ticker  Rendimiento
# 0    2010-01-04   27.341   27.406  137045797  aapl.us     0.002377
# 1    2010-01-05   27.508   27.454  167718021  aapl.us    -0.001963
# 2    2010-01-06   27.454   27.017  153403690  aapl.us    -0.015918
# 3    2010-01-07   27.108   26.968  132861904  aapl.us    -0.005165
# 4    2010-01-08   26.946   27.147  124730848  aapl.us     0.007459
# ...         ...      ...      ...        ...      ...          ...
# 1253 2014-12-24  106.570  106.040   15296050  aapl.us    -0.004973
# 1254 2014-12-26  106.130  107.910   35610489  aapl.us     0.016772
# 1255 2014-12-29  107.720  107.840   29133164  aapl.us     0.001114
# 1256 2014-12-30  107.570  106.510   31555587  aapl.us    -0.009854
# 1257 2014-12-31  106.810  104.490   43715939  aapl.us    -0.021721
#
# [1258 rows x 6 columns]

# %%
# encontremos la maxima presencia bursatil
max_presencias = 0
# hacemos un dict, key = nombre empresa, value = % presencia bursatil
dict_presencias = dict()

# calculo de la maxima presencia bursatil, valor que sera nuestra referencia
#vemos las presencia de todas las acciones y elegimos la mayor
for nombre, df in dict_frames.items():
    # calculamos presencia bursatil de esa accion
    pb = len(df.index)
    if pb > max_presencias:
        max_presencias = pb
        
# guardamos el porcentaje de capitalizacion de cada empresa en el dict
for nombre, df in dict_frames.items():
    # calculamos presencia bursatil de esa accion
    pb_porcentual = len(df.index)/max_presencias
    dict_presencias[nombre] = pb_porcentual
    
dict_presencias
# Out:
# {'a.us': 1.0,
#  'aal.us': 0.21144674085850557,
#  'aap.us': 0.9992050874403816,
#  'aapl.us': 1.0,
#  'abbv.us': 0.39825119236883944,
#  'abc.us': 1.0,
#  'abt.us': 1.0,
#  'acn.us': 0.9992050874403816,
#  'adbe.us': 1.0,
#  'adm.us': 1.0,
#  'adp.us': 1.0,
#  'ads.us': 0.9992050874403816,
#  'adsk.us': 1.0,
#  'aee.us': 1.0,
#  'aep.us': 1.0,
#  'aes.us': 1.0,
#  'aet.us': 1.0,
#  'afl.us': 1.0,
#  'aiv.us': 1.0,
#  'aiz.us': 0.9992050874403816,
#  'ajg.us': 0.9992050874403816,
#  'akam.us': 0.9992050874403816,
#  'alb.us': 0.9992050874403816,
#  'algn.us': 0.9992050874403816,
#  'alk.us': 0.9992050874403816,
#  'all.us': 1.0,
#  'alle.us': 0.21462639109697934,
#  'alxn.us': 0.9992050874403816,
#  'amat.us': 1.0,
#  'amd.us': 1.0,
#  'ame.us': 0.9992050874403816,
#  'amg.us': 0.9992050874403816,
#  'amgn.us': 1.0,
#  'amp.us': 0.9992050874403816,
#  'amt.us': 0.9992050874403816,
#  'amzn.us': 1.0,
#  'andv.us': 0.9992050874403816,
#  'anss.us': 0.9992050874403816,
#  'antm.us': 1.0,
#  'aon.us': 0.9992050874403816,
#  'aos.us': 0.9992050874403816,
#  'apa.us': 1.0,
#  'apc.us': 1.0,
#  'apd.us': 1.0,
#  'aph.us': 0.9992050874403816,
#  'are.us': 0.9992050874403816,
#  'arnc.us': 0.0,
#  'atvi.us': 0.9992050874403816,
#  'avgo.us': 0.9992050874403816,
#  'avy.us': 1.0,
#  'awk.us': 0.9992050874403816,
#  'axp.us': 1.0,
#  'ayi.us': 0.9992050874403816,
#  'azo.us': 1.0,
#  'ba.us': 1.0,
#  'bac.us': 1.0,
#  'bax.us': 1.0,
#  'bbt.us': 1.0,
#  'bby.us': 1.0,
#  'bdx.us': 1.0,
#  'ben.us': 1.0,
#  'bhf.us': 0.0,
#  'biib.us': 1.0,
#  'bk.us': 1.0,
#  'blk.us': 0.9992050874403816,
#  'bll.us': 1.0,
#  'bmy.us': 1.0,
#  'bsx.us': 1.0,
#  'bwa.us': 0.9992050874403816,
#  'bxp.us': 0.9992050874403816,
#  'c.us': 1.0,
#  'cag.us': 1.0,
#  'cah.us': 1.0,
#  'cat.us': 1.0,
#  'cb.us': 1.0,
#  'cbg.us': 0.9992050874403816,
#  'cboe.us': 0.910174880763116,
#  'cbs.us': 0.9992050874403816,
#  'cci.us': 0.9992050874403816,
#  'ccl.us': 0.9992050874403816,
#  'cdns.us': 0.9992050874403816,
#  'celg.us': 0.9992050874403816,
#  'cern.us': 0.9992050874403816,
#  'cf.us': 0.9992050874403816,
#  'cfg.us': 0.05405405405405406,
#  'chd.us': 0.9992050874403816,
#  'chk.us': 0.9992050874403816,
#  'chrw.us': 1.0,
#  'chtr.us': 0.985691573926868,
#  'ci.us': 0.9992050874403816,
#  'cinf.us': 1.0,
#  'cl.us': 0.9992050874403816,
#  'clx.us': 0.9992050874403816,
#  'cma.us': 0.9992050874403816,
#  'cmcsa.us': 1.0,
#  'cme.us': 0.9992050874403816,
#  'cmg.us': 0.9992050874403816,
#  'cmi.us': 0.9992050874403816,
#  'cms.us': 0.9992050874403816,
#  'cnc.us': 0.9992050874403816,
#  'cnp.us': 0.9992050874403816,
#  'cof.us': 0.9992050874403816,
#  'cog.us': 0.9992050874403816,
#  'col.us': 0.9992050874403816,
#  'coo.us': 0.9992050874403816,
#  'cop.us': 0.9992050874403816,
#  'cost.us': 1.0,
#  'cpb.us': 0.9992050874403816,
#  'crm.us': 0.9992050874403816,
#  'csco.us': 1.0,
#  'csra.us': 0.0,
#  'csx.us': 0.9992050874403816,
#  'ctas.us': 1.0,
#  'ctl.us': 0.9992050874403816,
#  'ctsh.us': 0.9992050874403816,
#  'ctxs.us': 1.0,
#  'cvs.us': 0.9992050874403816,
#  'cvx.us': 0.9992050874403816,
#  'cxo.us': 0.9992050874403816,
#  'd.us': 1.0,
#  'dal.us': 1.0,
#  'de.us': 1.0,
#  'dfs.us': 0.9992050874403816,
#  'dg.us': 0.9992050874403816,
#  'dgx.us': 1.0,
#  'dhi.us': 0.9992050874403816,
#  'dhr.us': 1.0,
#  'dis.us': 1.0,
#  'disca.us': 0.9992050874403816,
#  'disck.us': 0.9992050874403816,
#  'dish.us': 1.0,
#  'dlr.us': 0.9992050874403816,
#  'dltr.us': 1.0,
#  'dov.us': 1.0,
#  'dps.us': 0.9992050874403816,
#  'dre.us': 0.9992050874403816,
#  'dri.us': 1.0,
#  'dte.us': 1.0,
#  'duk.us': 1.0,
#  'dva.us': 0.9992050874403816,
#  'dvn.us': 1.0,
#  'dwdp.us': 1.0,
#  'dxc.us': 0.0,
#  'ea.us': 0.604133545310016,
#  'ebay.us': 1.0,
#  'ecl.us': 1.0,
#  'ed.us': 1.0,
#  'efx.us': 1.0,
#  'eix.us': 1.0,
#  'el.us': 0.9992050874403816,
#  'emn.us': 1.0,
#  'emr.us': 1.0,
#  'eog.us': 1.0,
#  'eqix.us': 0.9992050874403816,
#  'eqr.us': 1.0,
#  'eqt.us': 0.9992050874403816,
#  'es.us': 0.9992050874403816,
#  'esrx.us': 1.0,
#  'etfc.us': 0.9992050874403816,
#  'etn.us': 1.0,
#  'etr.us': 1.0,
#  'evhc.us': 0.2766295707472178,
#  'ew.us': 0.9992050874403816,
#  'exc.us': 1.0,
#  'expd.us': 1.0,
#  'expe.us': 0.9992050874403816,
#  'exr.us': 0.9992050874403816,
#  'f.us': 1.0,
#  'fast.us': 1.0,
#  'fbhs.us': 0.6462639109697933,
#  'fcx.us': 1.0,
#  'fdx.us': 1.0,
#  'fe.us': 1.0,
#  'ffiv.us': 0.9992050874403816,
#  'fis.us': 0.9992050874403816,
#  'fisv.us': 1.0,
#  'fitb.us': 1.0,
#  'fl.us': 0.9992050874403816,
#  'flir.us': 0.9992050874403816,
#  'flr.us': 1.0,
#  'fls.us': 0.9992050874403816,
#  'fmc.us': 0.9992050874403816,
#  'fox.us': 0.9992050874403816,
#  'foxa.us': 0.9992050874403816,
#  'frt.us': 0.9992050874403816,
#  'fti.us': 0.9992050874403816,
#  'ftv.us': 0.0,
#  'gd.us': 1.0,
#  'ge.us': 1.0,
#  'ggp.us': 0.9992050874403816,
#  'gild.us': 1.0,
#  'gis.us': 1.0,
#  'glw.us': 1.0,
#  'gm.us': 0.8235294117647058,
#  'goog.us': 0.1534181240063593,
#  'googl.us': 1.0,
#  'gpc.us': 1.0,
#  'gpn.us': 0.9992050874403816,
#  'gps.us': 1.0,
#  'grmn.us': 1.0,
#  'gs.us': 1.0,
#  'gt.us': 1.0,
#  'gww.us': 1.0,
#  'hal.us': 1.0,
#  'has.us': 1.0,
#  'hban.us': 1.0,
#  'hbi.us': 0.9992050874403816,
#  'hca.us': 0.7599364069952306,
#  'hcn.us': 0.9992050874403816,
#  'hcp.us': 0.9992050874403816,
#  'hd.us': 1.0,
#  'hes.us': 0.9992050874403816,
#  'hig.us': 1.0,
#  'hii.us': 0.7480127186009539,
#  'hlt.us': 0.20985691573926868,
#  'hog.us': 0.9992050874403816,
#  'holx.us': 0.9992050874403816,
#  'hon.us': 1.0,
#  'hp.us': 0.9992050874403816,
#  'hpe.us': 0.0,
#  'hpq.us': 1.0,
#  'hrb.us': 1.0,
#  'hrl.us': 0.9992050874403816,
#  'hrs.us': 0.9992050874403816,
#  'hsic.us': 1.0,
#  'hst.us': 0.9992050874403816,
#  'hsy.us': 1.0,
#  'hum.us': 1.0,
#  'ibm.us': 1.0,
#  'ice.us': 0.9992050874403816,
#  'idxx.us': 0.9992050874403816,
#  'iff.us': 1.0,
#  'ilmn.us': 0.9992050874403816,
#  'incy.us': 0.9992050874403816,
#  'info.us': 0.10731319554848967,
#  'intc.us': 1.0,
#  'intu.us': 1.0,
#  'ip.us': 1.0,
#  'ipg.us': 1.0,
#  'ir.us': 1.0,
#  'irm.us': 0.9992050874403816,
#  'isrg.us': 0.9992050874403816,
#  'it.us': 0.9992050874403816,
#  'itw.us': 1.0,
#  'ivz.us': 0.9992050874403816,
#  'jbht.us': 0.9992050874403816,
#  'jci.us': 1.0,
#  'jec.us': 0.9992050874403816,
#  'jnj.us': 1.0,
#  'jnpr.us': 1.0,
#  'jpm.us': 1.0,
#  'jwn.us': 1.0,
#  'k.us': 1.0,
#  'key.us': 1.0,
#  'khc.us': 0.0,
#  'kim.us': 0.9992050874403816,
#  'klac.us': 1.0,
#  'kmb.us': 1.0,
#  'kmi.us': 0.7742448330683624,
#  'kmx.us': 0.9992050874403816,
#  'ko.us': 1.0,
#  'kors.us': 0.6057233704292527,
#  'kr.us': 1.0,
#  'kss.us': 1.0,
#  'ksu.us': 0.9992050874403816,
#  'l.us': 0.9992050874403816,
#  'lb.us': 1.0,
#  'leg.us': 1.0,
#  'len.us': 0.9992050874403816,
#  'lh.us': 0.9992050874403816,
#  'lkq.us': 0.9992050874403816,
#  'lll.us': 0.9992050874403816,
#  'lly.us': 1.0,
#  'lmt.us': 1.0,
#  'lnc.us': 1.0,
#  'lnt.us': 0.9992050874403816,
#  'low.us': 1.0,
#  'lrcx.us': 1.0,
#  'luk.us': 0.9992050874403816,
#  'luv.us': 1.0,
#  'lyb.us': 0.9364069952305246,
#  'm.us': 0.9992050874403816,
#  'ma.us': 0.9992050874403816,
#  'maa.us': 0.9992050874403816,
#  'mac.us': 0.9992050874403816,
#  'mar.us': 1.0,
#  'mas.us': 1.0,
#  'mat.us': 1.0,
#  'mcd.us': 1.0,
#  'mchp.us': 1.0,
#  'mck.us': 1.0,
#  'mco.us': 1.0,
#  'mdlz.us': 1.0,
#  'mdt.us': 1.0,
#  'met.us': 1.0,
#  'mgm.us': 0.9992050874403816,
#  'mhk.us': 0.9992050874403816,
#  'mkc.us': 1.0,
#  'mlm.us': 0.9992050874403816,
#  'mmc.us': 1.0,
#  'mmm.us': 1.0,
#  'mnst.us': 0.5945945945945946,
#  'mo.us': 1.0,
#  'mon.us': 1.0,
#  'mos.us': 0.9992050874403816,
#  'mpc.us': 0.6979332273449921,
#  'mrk.us': 1.0,
#  'mro.us': 1.0,
#  'ms.us': 0.9992050874403816,
#  'msft.us': 1.0,
#  'msi.us': 1.0,
#  'mtb.us': 1.0,
#  'mtd.us': 0.9992050874403816,
#  'mu.us': 1.0,
#  'myl.us': 0.9992050874403816,
#  'navi.us': 0.13195548489666137,
#  'nbl.us': 0.9992050874403816,
#  'nclh.us': 0.390302066772655,
#  'nee.us': 0.9992050874403816,
#  'nem.us': 1.0,
#  'nflx.us': 0.9992050874403816,
#  'nfx.us': 0.9992050874403816,
#  'ni.us': 1.0,
#  'nke.us': 1.0,
#  'nlsn.us': 0.7845786963434023,
#  'noc.us': 1.0,
#  'nov.us': 0.9992050874403816,
#  'nrg.us': 0.9992050874403816,
#  'nsc.us': 1.0,
#  'ntap.us': 1.0,
#  'ntrs.us': 1.0,
#  'nue.us': 1.0,
#  'nvda.us': 1.0,
#  'nwl.us': 1.0,
#  'nws.us': 0.3052464228934817,
#  'nwsa.us': 0.3052464228934817,
#  'o.us': 0.9992050874403816,
#  'oke.us': 0.9992050874403816,
#  'omc.us': 1.0,
#  'orcl.us': 1.0,
#  'orly.us': 0.9992050874403816,
#  'oxy.us': 1.0,
#  'payx.us': 1.0,
#  'pbct.us': 0.9992050874403816,
#  'pcar.us': 1.0,
#  'pcg.us': 1.0,
#  'pcln.us': 0.9992050874403816,
#  'pdco.us': 1.0,
#  'peg.us': 1.0,
#  'pep.us': 1.0,
#  'pfe.us': 1.0,
#  'pfg.us': 1.0,
#  'pg.us': 1.0,
#  'pgr.us': 1.0,
#  'ph.us': 1.0,
#  'phm.us': 1.0,
#  'pkg.us': 0.9992050874403816,
#  'pki.us': 1.0,
#  'pld.us': 1.0,
#  'pm.us': 0.9992050874403816,
#  'pnc.us': 1.0,
#  'pnr.us': 0.9992050874403816,
#  'pnw.us': 1.0,
#  'ppg.us': 1.0,
#  'ppl.us': 1.0,
#  'prgo.us': 0.9992050874403816,
#  'pru.us': 1.0,
#  'psa.us': 0.9992050874403816,
#  'psx.us': 0.5317965023847376,
#  'pvh.us': 0.9992050874403816,
#  'pwr.us': 0.9992050874403816,
#  'px.us': 1.0,
#  'pxd.us': 0.9992050874403816,
#  'pypl.us': 0.0,
#  'qcom.us': 1.0,
#  'qrvo.us': 0.0,
#  'rcl.us': 0.9992050874403816,
#  're.us': 0.9992050874403816,
#  'reg.us': 0.9992050874403816,
#  'regn.us': 0.9992050874403816,
#  'rf.us': 1.0,
#  'rhi.us': 1.0,
#  'rht.us': 0.9992050874403816,
#  'rjf.us': 0.9992050874403816,
#  'rl.us': 0.9992050874403816,
#  'rmd.us': 0.9992050874403816,
#  'rok.us': 1.0,
#  'rop.us': 0.9992050874403816,
#  'rost.us': 1.0,
#  'rrc.us': 0.9992050874403816,
#  'rsg.us': 0.9992050874403816,
#  'rtn.us': 1.0,
#  'sbac.us': 0.9992050874403816,
#  'sbux.us': 1.0,
#  'scg.us': 0.9992050874403816,
#  'schw.us': 0.9992050874403816,
#  'see.us': 1.0,
#  'shw.us': 1.0,
#  'sig.us': 0.9992050874403816,
#  'sjm.us': 0.9992050874403816,
#  'slb.us': 1.0,
#  'slg.us': 0.9992050874403816,
#  'sna.us': 1.0,
#  'sni.us': 0.9992050874403816,
#  'snps.us': 1.0,
#  'so.us': 1.0,
#  'spg.us': 1.0,
#  'srcl.us': 0.9992050874403816,
#  'sre.us': 1.0,
#  'sti.us': 1.0,
#  'stt.us': 1.0,
#  'stx.us': 0.9992050874403816,
#  'stz.us': 0.9992050874403816,
#  'swk.us': 1.0,
#  'swks.us': 0.9992050874403816,
#  'syf.us': 0.08426073131955485,
#  'syk.us': 1.0,
#  'symc.us': 1.0,
#  'syy.us': 1.0,
#  't.us': 1.0,
#  'tap.us': 0.9992050874403816,
#  'tdg.us': 0.9992050874403816,
#  'tel.us': 0.9992050874403816,
#  'tgt.us': 1.0,
#  'tif.us': 1.0,
#  'tjx.us': 1.0,
#  'tmk.us': 1.0,
#  'tmo.us': 1.0,
#  'trip.us': 0.6033386327503975,
#  'trow.us': 1.0,
#  'trv.us': 0.9992050874403816,
#  'tsco.us': 0.9992050874403816,
#  'tsn.us': 0.9992050874403816,
#  'tss.us': 0.9992050874403816,
#  'twx.us': 1.0,
#  'txn.us': 1.0,
#  'ua.us': 0.0,
#  'uaa.us': 0.9992050874403816,
#  'ual.us': 1.0,
#  'udr.us': 0.9992050874403816,
#  'ulta.us': 0.9992050874403816,
#  'unh.us': 1.0,
#  'unm.us': 1.0,
#  'unp.us': 1.0,
#  'ups.us': 1.0,
#  'usb.us': 1.0,
#  'utx.us': 1.0,
#  'v.us': 0.9992050874403816,
#  'var.us': 0.9992050874403816,
#  'vfc.us': 1.0,
#  'viab.us': 0.6136724960254372,
#  'vlo.us': 0.9992050874403816,
#  'vmc.us': 1.0,
#  'vno.us': 0.9992050874403816,
#  'vrsk.us': 0.9992050874403816,
#  'vrsn.us': 1.0,
#  'vrtx.us': 0.9984101748807631,
#  'vtr.us': 0.9992050874403816,
#  'vz.us': 1.0,
#  'wat.us': 1.0,
#  'wba.us': 1.0,
#  'wdc.us': 0.9992050874403816,
#  'wec.us': 1.0,
#  'wfc.us': 1.0,
#  'whr.us': 1.0,
#  'wltw.us': 0.9992050874403816,
#  'wm.us': 0.9992050874403816,
#  'wmb.us': 1.0,
#  'wmt.us': 1.0,
#  'wrk.us': 0.0,
#  'wu.us': 0.9992050874403816,
#  'wy.us': 1.0,
#  'wyn.us': 0.9992050874403816,
#  'wynn.us': 0.9992050874403816,
#  'xec.us': 0.9992050874403816,
#  'xel.us': 1.0,
#  'xl.us': 1.0,
#  'xlnx.us': 1.0,
#  'xom.us': 1.0,
#  'xray.us': 1.0,
#  'xrx.us': 1.0,
#  'xyl.us': 0.6303656597774245,
#  'yum.us': 1.0,
#  'zbh.us': 1.0,
#  'zion.us': 1.0,
#  'zts.us': 0.383147853736089}

# %%
# filtramos con aquellas empresas que cumplen con el 99,9% de las presencias
# creamos un nuevo dict para evitar cambios del dict en la iteracion
dict_frames_nuevo = dict_frames.copy()
no_sirven = 0
for accion, df in dict_frames.items():
    # si tiene menos del 99,9% de presencias se elimina
    if dict_presencias[accion] < 0.999:
        del dict_frames_nuevo[accion]


# actualizamos las acciones
dict_frames = dict_frames_nuevo

#imprimimos la cantidad de acciones
print(len(dict_frames))
# Out:
# 443

# %%
# hacemos el calculo de matriz de covarianza por industria con lo que tenemos por mientras
# para los datos iniciales
Empresa = namedtuple('Empresa', 'nombre industria sector marketcap')
originales_df =  pd.read_csv("companies.csv", sep=",")
originales_df["ticker"] = originales_df["ticker"].str.lower()
originales_df = originales_df[['ticker', 'company name', 'industry','sector', 'market cap']]
lista_tickers_original = list(originales_df['ticker'])
lista_sectores_original = list(originales_df['sector'])


#dict que guardara las matrices de covarianza por sector
dict_matrices = dict()
for sector in set(lista_sectores_original):
    df_rendimientos = pd.DataFrame()  # data frame vacio que iremos rellenando
    for accion, df in dict_frames_nuevo.items():
        if sector != df['Sector'][0]:
            continue
        else: 
            df_rendimientos[accion] = df['Rendimiento']
    # calculamos la matriz        
    matriz_cov = df_rendimientos.cov()

# %%
# calculo de la gran matriz de covarianza completa
# crearemos un nuevo data frame que tiene en cada columna los rendimientos de una empresa
# la matriz de covarianza se calcula a partir de este dataframe

df_rendimientos = pd.DataFrame()  # data frame vacio que iremos rellenando

for accion, df in dict_frames.items():
    
    df_rendimientos[accion] = df['Rendimiento']
    
matriz_cov = df_rendimientos.cov()
# guardamos un excel con la matriz
path = f'S&P_cov.csv'
matriz_cov.to_csv(path)

# %%
# mostramos la matriz
matriz_cov
# Out:
#              a.us    aap.us   aapl.us    abc.us    abt.us    acn.us   adbe.us  \
# a.us     0.000269  0.000004  0.000077  0.000075  0.000056  0.000018  0.000114
# aap.us   0.000004  0.000180  0.000010 -0.000002 -0.000003  0.000040  0.000014
# aapl.us  0.000077  0.000010  0.000181  0.000043  0.000027  0.000017  0.000067
# abc.us   0.000075 -0.000002  0.000043  0.000124  0.000035  0.000005  0.000054
# abt.us   0.000056 -0.000003  0.000027  0.000035  0.000084  0.000007  0.000039
# ...           ...       ...       ...       ...       ...       ...       ...
# xray.us  0.000110  0.000003  0.000050  0.000052  0.000039  0.000009  0.000077
# xrx.us   0.000120  0.000011  0.000075  0.000055  0.000046  0.000016  0.000093
# yum.us   0.000084  0.000009  0.000056  0.000046  0.000034  0.000009  0.000067
# zbh.us   0.000098  0.000003  0.000049  0.000054  0.000044  0.000007  0.000065
# zion.us  0.000157  0.000024  0.000076  0.000057  0.000054  0.000022  0.000105
#
#            adm.us    adp.us    ads.us  ...    xec.us    xel.us     xl.us  \
# a.us     0.000083  0.000075  0.000042  ...  0.000032  0.000039  0.000108
# aap.us   0.000004  0.000004  0.000059  ...  0.000072  0.000007  0.000014
# aapl.us  0.000041  0.000043  0.000030  ...  0.000031  0.000021  0.000059
# abc.us   0.000047  0.000041  0.000016  ...  0.000024  0.000024  0.000057
# abt.us   0.000041  0.000036  0.000010  ...  0.000006  0.000028  0.000038
# ...           ...       ...       ...  ...       ...       ...       ...
# xray.us  0.000059  0.000056  0.000032  ...  0.000019  0.000027  0.000076
# xrx.us   0.000069  0.000064  0.000027  ...  0.000031  0.000030  0.000094
# yum.us   0.000051  0.000048  0.000023  ...  0.000018  0.000033  0.000065
# zbh.us   0.000053  0.000049  0.000022  ...  0.000014  0.000029  0.000064
# zion.us  0.000090  0.000076  0.000053  ...  0.000034  0.000040  0.000134
#
#           xlnx.us    xom.us   xray.us    xrx.us    yum.us    zbh.us   zion.us
# a.us     0.000108  0.000072  0.000110  0.000120  0.000084  0.000098  0.000157
# aap.us   0.000020  0.000003  0.000003  0.000011  0.000009  0.000003  0.000024
# aapl.us  0.000067  0.000041  0.000050  0.000075  0.000056  0.000049  0.000076
# abc.us   0.000045  0.000033  0.000052  0.000055  0.000046  0.000054  0.000057
# abt.us   0.000032  0.000032  0.000039  0.000046  0.000034  0.000044  0.000054
# ...           ...       ...       ...       ...       ...       ...       ...
# xray.us  0.000070  0.000053  0.000140  0.000082  0.000056  0.000075  0.000103
# xrx.us   0.000097  0.000064  0.000082  0.000250  0.000070  0.000069  0.000133
# yum.us   0.000058  0.000044  0.000056  0.000070  0.000141  0.000048  0.000081
# zbh.us   0.000058  0.000046  0.000075  0.000069  0.000048  0.000135  0.000087
# zion.us  0.000101  0.000073  0.000103  0.000133  0.000081  0.000087  0.000360
#
# [443 rows x 443 columns]
